# %%
import numpy as np
import pandas as pd

# %%
d=pd.read_csv("topanime.csv")
d.head
print(d.isnull())
# Out:
#       Rank  Title  Popularity  Genre  Studio   Type  Episodes  Duration  \
# 0    False  False       False  False   False  False     False     False
# 1    False  False       False  False   False  False     False     False
# 2    False  False       False  False   False  False     False     False
# 3    False  False       False  False   False  False     False     False
# 4    False  False       False  False   False  False     False     False
# ..     ...    ...         ...    ...     ...    ...       ...       ...
# 245  False  False       False  False   False  False     False     False
# 246  False  False       False  False   False  False     False     False
# 247  False  False       False  False   False  False     False     False
# 248  False  False       False  False   False  False     False     False
# 249  False  False       False  False   False  False     False     False
#
#      Start_date  End_date  Members  Score
# 0         False     False    False  False
# 1         False     False    False  False
# 2         False     False    False  False
# 3         False     False    False  False
# 4         False     False    False  False
# ..          ...       ...      ...    ...
# 245       False     False    False  False
# 246       False     False    False  False
# 247       False     False    False  False
# 248       False     False    False  False
# 249       False     False    False  False
#
# [250 rows x 12 columns]

# %%
a=d.isnull().sum()
print(a)
# Out:
# Rank          0
# Title         0
# Popularity    0
# Genre         1
# Studio        2
# Type          0
# Episodes      1
# Duration      0
# Start_date    0
# End_date      2
# Members       2
# Score         0
# dtype: int64

# %%
d.dropna()
# Out:
#      Rank                                              Title  Popularity  \
# 0       1  Shingeki no Kyojin: The Final Season - Kankets...         609
# 1       2                   Fullmetal Alchemist: Brotherhood           3
# 2       3                          Bleach: Sennen Kessen-hen         508
# 3       4                                        Steins;Gate          13
# 4       5                                           Gintama°         335
# ..    ...                                                ...         ...
# 245   246                                          Blue Lock         439
# 246   247  Detective Conan Movie 06: The Phantom of Baker...        2289
# 247   248                      Diamond no Ace: Second Season        1541
# 248   249                                Hibike! Euphonium 2        1017
# 249   250                                      Ashita no Joe        2112
#
#                                  Genre                    Studio     Type  \
# 0              Action, Drama, Suspense                     MAPPA  Special
# 1    Action, Adventure, Drama, Fantasy                     Bones       TV
# 2           Action, Adventure, Fantasy                   Pierrot       TV
# 3              Drama, Sci-Fi, Suspense                 White Fox       TV
# 4               Action, Comedy, Sci-Fi     Bandai Namco Pictures       TV
# ..                                 ...                       ...      ...
# 245                             Sports                      8bit       TV
# 246                 Adventure, Mystery         TMS Entertainment    Movie
# 247                             Sports  Production I.G, Madhouse       TV
# 248                              Drama           Kyoto Animation       TV
# 249                      Drama, Sports          Mushi Production       TV
#
#      Episodes  Duration Start_date End_date    Members  Score
# 0         2.0        61     23-Mar     2023   347875.0   9.17
# 1        64.0        24      9-Apr   10-Jul  3109951.0   9.11
# 2        13.0        24     22-Oct   22-Dec   404036.0   9.09
# 3        24.0        24     11-Apr   11-Sep  2393767.0   9.08
# 4        51.0        24     15-Apr   16-Mar   581994.0   9.07
# ..        ...       ...        ...      ...        ...    ...
# 245      24.0        24     22-Oct   23-Mar   459426.0   8.30
# 246       1.0       107      2-Apr    2-Apr    73487.0   8.30
# 247      51.0        24     15-Apr   16-Mar   130376.0   8.30
# 248      13.0        23     16-Oct   16-Dec   213707.0   8.30
# 249      79.0        25     Apr-70   Sep-71    83604.0   8.29
#
# [244 rows x 12 columns]

# %%
a=d.isnull().sum()
print(a)
# Out:
# Rank          0
# Title         0
# Popularity    0
# Genre         1
# Studio        2
# Type          0
# Episodes      1
# Duration      0
# Start_date    0
# End_date      2
# Members       2
# Score         0
# dtype: int64

# %%
total = np.product(d.shape)
t_missing= a.sum()
(t_missing/total) * 100
# Out:
# 0.26666666666666666

# %%
d.fillna(method = 'bfill', axis=0).fillna(0)
# Out:
#      Rank                                              Title  Popularity  \
# 0       1  Shingeki no Kyojin: The Final Season - Kankets...         609
# 1       2                   Fullmetal Alchemist: Brotherhood           3
# 2       3                          Bleach: Sennen Kessen-hen         508
# 3       4                                        Steins;Gate          13
# 4       5                                           Gintama°         335
# ..    ...                                                ...         ...
# 245   246                                          Blue Lock         439
# 246   247  Detective Conan Movie 06: The Phantom of Baker...        2289
# 247   248                      Diamond no Ace: Second Season        1541
# 248   249                                Hibike! Euphonium 2        1017
# 249   250                                      Ashita no Joe        2112
#
#                                  Genre                    Studio     Type  \
# 0              Action, Drama, Suspense                     MAPPA  Special
# 1    Action, Adventure, Drama, Fantasy                     Bones       TV
# 2           Action, Adventure, Fantasy                   Pierrot       TV
# 3              Drama, Sci-Fi, Suspense                 White Fox       TV
# 4               Action, Comedy, Sci-Fi     Bandai Namco Pictures       TV
# ..                                 ...                       ...      ...
# 245                             Sports                      8bit       TV
# 246                 Adventure, Mystery         TMS Entertainment    Movie
# 247                             Sports  Production I.G, Madhouse       TV
# 248                              Drama           Kyoto Animation       TV
# 249                      Drama, Sports          Mushi Production       TV
#
#      Episodes  Duration Start_date End_date    Members  Score
# 0         2.0        61     23-Mar     2023   347875.0   9.17
# 1        64.0        24      9-Apr   10-Jul  3109951.0   9.11
# 2        13.0        24     22-Oct   22-Dec   404036.0   9.09
# 3        24.0        24     11-Apr   11-Sep  2393767.0   9.08
# 4        51.0        24     15-Apr   16-Mar   581994.0   9.07
# ..        ...       ...        ...      ...        ...    ...
# 245      24.0        24     22-Oct   23-Mar   459426.0   8.30
# 246       1.0       107      2-Apr    2-Apr    73487.0   8.30
# 247      51.0        24     15-Apr   16-Mar   130376.0   8.30
# 248      13.0        23     16-Oct   16-Dec   213707.0   8.30
# 249      79.0        25     Apr-70   Sep-71    83604.0   8.29
#
# [250 rows x 12 columns]

# %%
a=d.isnull().sum()
print(a)
# Out:
# Rank          0
# Title         0
# Popularity    0
# Genre         1
# Studio        2
# Type          0
# Episodes      1
# Duration      0
# Start_date    0
# End_date      2
# Members       2
# Score         0
# dtype: int64

# %%
total = np.product(d.shape)
t_missing= a.sum()
(t_missing/total) * 100
# Out:
# 0.26666666666666666

# %%
d.head(40)
# Out:
#     Rank                                              Title  Popularity  \
# 0      1  Shingeki no Kyojin: The Final Season - Kankets...         609
# 1      2                   Fullmetal Alchemist: Brotherhood           3
# 2      3                          Bleach: Sennen Kessen-hen         508
# 3      4                                        Steins;Gate          13
# 4      5                                           Gintama°         335
# 5      6         Kaguya-sama wa Kokurasetai: Ultra Romantic         221
# 6      7                 Shingeki no Kyojin Season 3 Part 2          26
# 7      8                                 Gintama: The Final        1581
# 8      9                                           Gintama'         385
# 9     10                             Hunter x Hunter (2011)          10
# 10    11                               Ginga Eiyuu Densetsu         724
# 11    12                                Gintama': Enchousen         712
# 12    13                           Fruits Basket: The Final         494
# 13    14                                           Gintama.         744
# 14    15  Kaguya-sama wa Kokurasetai: First Kiss wa Owar...        1872
# 15    16                         3-gatsu no Lion 2nd Season         550
# 16    17                               Clannad: After Story         111
# 17    18                                            Gintama         138
# 18    19                                     Koe no Katachi          19
# 19    20  Gintama Movie 2: Kanketsu-hen - Yorozuya yo Ei...         960
# 20    21                                   Bocchi the Rock!         597
# 21    22                 Code Geass: Hangyaku no Lelouch R2          47
# 22    23                            Violet Evergarden Movie         375
# 23    24                         Owarimonogatari 2nd Season         557
# 24    25   Gintama.: Shirogane no Tamashii-hen - Kouhan-sen        1187
# 25    26                                            Monster         145
# 26    27                                     Kimi no Na wa.          11
# 27    28                Gintama.: Shirogane no Tamashii-hen        1106
# 28    29                      Kimetsu no Yaiba: Yuukaku-hen         108
# 29    30                                 Kingdom 3rd Season        2064
# 30    31                                  Mob Psycho 100 II          76
# 31    32               Shingeki no Kyojin: The Final Season          41
# 32    33                   Kizumonogatari III: Reiketsu-hen         467
# 33    34                      Sen to Chihiro no Kamikakushi          44
# 34    35  Haikyuu!! Karasuno Koukou vs. Shiratorizawa Ga...         114
# 35    36                   Monogatari Series: Second Season         291
# 36    37        Shingeki no Kyojin: The Final Season Part 2         124
# 37    38                                  Shiguang Dailiren         779
# 38    39                                       Cowboy Bebop          43
# 39    40                                     Hajime no Ippo         369
#
#                                      Genre  \
# 0                  Action, Drama, Suspense
# 1        Action, Adventure, Drama, Fantasy
# 2               Action, Adventure, Fantasy
# 3                  Drama, Sci-Fi, Suspense
# 4                   Action, Comedy, Sci-Fi
# 5                          Comedy, Romance
# 6                            Action, Drama
# 7            Action, Comedy, Drama, Sci-Fi
# 8                   Action, Comedy, Sci-Fi
# 9               Action, Adventure, Fantasy
# 10                           Drama, Sci-Fi
# 11                  Action, Comedy, Sci-Fi
# 12            Drama, Romance, Supernatural
# 13                  Action, Comedy, Sci-Fi
# 14                  Comedy, Drama, Romance
# 15                    Drama, Slice of Life
# 16            Drama, Romance, Supernatural
# 17                  Action, Comedy, Sci-Fi
# 18                    Award Winning, Drama
# 19                  Action, Comedy, Sci-Fi
# 20                                  Comedy
# 21    Action, Award Winning, Drama, Sci-Fi
# 22           Award Winning, Drama, Fantasy
# 23           Comedy, Mystery, Supernatural
# 24                  Action, Comedy, Sci-Fi
# 25                Drama, Mystery, Suspense
# 26      Award Winning, Drama, Supernatural
# 27                  Action, Comedy, Sci-Fi
# 28                         Action, Fantasy
# 29                                  Action
# 30            Action, Comedy, Supernatural
# 31                           Action, Drama
# 32           Action, Mystery, Supernatural
# 33  Adventure, Award Winning, Supernatural
# 34                                  Sports
# 35  Comedy, Mystery, Romance, Supernatural
# 36                           Action, Drama
# 37                     Drama, Supernatural
# 38           Action, Award Winning, Sci-Fi
# 39                                  Sports
#
#                                  Studio     Type  Episodes  Duration  \
# 0                                 MAPPA  Special       2.0        61
# 1                                 Bones       TV      64.0        24
# 2                               Pierrot       TV      13.0        24
# 3                             White Fox       TV      24.0        24
# 4                 Bandai Namco Pictures       TV      51.0        24
# 5                          A-1 Pictures       TV      13.0        23
# 6                            Wit Studio       TV      10.0        23
# 7                 Bandai Namco Pictures    Movie       1.0       104
# 8                               Sunrise       TV      51.0        24
# 9                              Madhouse       TV     148.0        23
# 10  K-Factory, Kitty Film Mitaka Studio      OVA     110.0        26
# 11                              Sunrise       TV      13.0        24
# 12                    TMS Entertainment       TV      13.0        23
# 13                Bandai Namco Pictures       TV      12.0        24
# 14                         A-1 Pictures    Movie       1.0        96
# 15                                Shaft       TV      22.0        25
# 16                      Kyoto Animation       TV      24.0        24
# 17                              Sunrise       TV     201.0        24
# 18                      Kyoto Animation    Movie       1.0       130
# 19                              Sunrise    Movie       1.0       110
# 20                          CloverWorks       TV      12.0        23
# 21                              Sunrise       TV      25.0        24
# 22                      Kyoto Animation    Movie       1.0       140
# 23                                Shaft       TV       7.0        22
# 24                Bandai Namco Pictures       TV      14.0        24
# 25                             Madhouse       TV      74.0        24
# 26                     CoMix Wave Films    Movie       1.0       106
# 27                Bandai Namco Pictures       TV      12.0        24
# 28                             ufotable       TV      11.0        26
# 29             Pierrot, Studio Signpost       TV      26.0        25
# 30                                Bones       TV      13.0        24
# 31                                MAPPA       TV      16.0        23
# 32                                Shaft    Movie       1.0        83
# 33                        Studio Ghibli    Movie       1.0       124
# 34                       Production I.G       TV      10.0        24
# 35                                Shaft       TV      26.0        25
# 36                                MAPPA       TV      12.0        23
# 37                           Studio LAN      ONA      11.0        23
# 38                              Sunrise       TV      26.0        24
# 39                             Madhouse       TV      75.0        23
#
#    Start_date End_date    Members  Score
# 0      23-Mar     2023   347875.0   9.17
# 1       9-Apr   10-Jul  3109951.0   9.11
# 2      22-Oct   22-Dec   404036.0   9.09
# 3      11-Apr   11-Sep  2393767.0   9.08
# 4      15-Apr   16-Mar   581994.0   9.07
# 5      22-Apr   22-Jun   772019.0   9.06
# 6      19-Apr   19-Jul  2045115.0   9.06
# 7      21-Jan   21-Jan   126411.0   9.05
# 8      11-Apr   12-Mar   513321.0   9.04
# 9      11-Oct   14-Sep  2596435.0   9.04
# 10     Jan-88   Mar-97   299874.0   9.03
# 11     12-Oct   13-Mar   303048.0   9.03
# 12     21-Apr   21-Jun   412917.0   9.01
# 13     17-Jan   17-Mar   291330.0   8.99
# 14     22-Dec   22-Dec   100847.0   8.95
# 15     17-Oct   18-Mar   376498.0   8.94
# 16      8-Oct    9-Mar  1134162.0   8.94
# 17      6-Apr   10-Mar  1006869.0   8.94
# 18     16-Sep   16-Sep  2142847.0   8.94
# 19     13-Jul   13-Jul   224966.0   8.92
# 20     22-Oct   22-Dec   354287.0   8.91
# 21      8-Apr    8-Sep  1670371.0   8.91
# 22     20-Sep   20-Sep   524302.0   8.91
# 23     17-Aug   17-Aug   373320.0   8.89
# 24     18-Jul   18-Oct   180818.0   8.88
# 25      4-Apr    5-Sep   973346.0   8.86
# 26     16-Aug   16-Aug  2541050.0   8.85
# 27     18-Jan   18-Mar   195242.0   8.81
# 28     21-Dec   22-Feb  1161501.0   8.81
# 29     20-Apr   21-Oct    87348.0   8.81
# 30     19-Jan   19-Apr  1396286.0   8.80
# 31     20-Dec   21-Mar  1792439.0   8.80
# 32     17-Jan   17-Jan   431963.0   8.79
# 33      1-Jul    1-Jul  1726236.0   8.78
# 34     16-Oct   16-Dec  1119267.0   8.78
# 35     13-Jul   13-Dec   639359.0   8.77
# 36     22-Jan   22-Apr  1077191.0   8.77
# 37     21-Apr   21-Jul   279830.0   8.75
# 38     Apr-98   Apr-99  1737593.0   8.75
# 39     Oct-00    2-Mar   531069.0   8.75

# %%
from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(_df_53['Genre'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(_df_53, x='Rank', y='Genre', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['Genre'].value_counts()
    for x_label, grp in _df_48.groupby('Title')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('Title')
_ = plt.ylabel('Genre')

# %%
from matplotlib import pyplot as plt
_df_1['Popularity'].plot(kind='hist', bins=20, title='Popularity')
plt.gca().spines[['top', 'right',]].set_visible(False)
